# %%
from transformers import AutoTokenizer, pipeline, GPT2LMHeadModel, GPT2Tokenizer

# Tokenization

# To use tokenizers, we import them from the transformers library

# There are many available, use the ID of the model you want to use
# Qwen "Qwen/Qwen2-0.5B"
# GPT-2 "openai-community/gpt2"
# SmolLM "HuggingFaceTB/SomlLM-135M"

model_id = "openai-community/gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Use GPT2LMHeadModel for access to token probabilities
model = GPT2LMHeadModel.from_pretrained(model_id)

# %% [markdown]
# # P+7

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch
import torch.nn.functional as F

def predict_next_word(text_input):
    gpt2_model = GPT2LMHeadModel.from_pretrained('gpt2')
    gpt2_tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
    gpt2_model.eval()

    encoded_input = gpt2_tokenizer.encode(text_input, return_tensors='pt')

    with torch.no_grad():
        model_output = gpt2_model(encoded_input)
        word_predictions = model_output[0]

    next_word_logits = word_predictions[0, -1, :]
    word_probabilities = F.softmax(next_word_logits, dim=0)

    top_probs, top_indices = torch.topk(word_probabilities, k=7)
    predicted_words = [gpt2_tokenizer.decode(idx.item()).strip() for idx in top_indices]

    highlighted_words = ', '.join(
        f"**{word}**" if i == 6 else word for i, word in enumerate(predicted_words)
    )
    print(f"Text: {text_input}\nTop 7 words: {highlighted_words}\n{'-' * 30}")

    return predicted_words[6]


def modify_poem(poem):
    poem_lines = [line.strip() for line in poem.split('\n') if line.strip()]
    updated_lines = []

    for current_line in poem_lines:
        line_words = current_line.split()
        if not line_words:
            updated_lines.append(current_line)
            continue

        line_context = ' '.join(line_words[:-1])
        replacement_word = predict_next_word(line_context)
        modified_line = f"{line_context} {replacement_word}"
        updated_lines.append(modified_line)

    return '\n'.join(updated_lines)


# Poem
poem = """One must have a mind of winter
To regard the frost and the boughs
Of the pine-trees crusted with snow;
And have been cold a long time
To behold the junipers shagged with ice,
The spruces rough in the distant glitter
Of the January sun; and not to think
Of any misery in the sound of the wind,
In the sound of a few leaves,
Which is the sound of the land
Full of the same wind
That is blowing in the same bare place
For the listener, who listens in the snow,
And, nothing himself, beholds
Nothing that is not there and the nothing that is."""

# Printing
print(f"Original Poem:\n{'-' * 50}\n{poem}\n")
print(f"New Poem (P+7):\n{'-' * 50}")
modified_poem = modify_poem(poem)
print(modified_poem)
# Out:
# Original Poem:
# --------------------------------------------------
# One must have a mind of winter
# To regard the frost and the boughs
# Of the pine-trees crusted with snow;
# And have been cold a long time
# To behold the junipers shagged with ice,
# The spruces rough in the distant glitter
# Of the January sun; and not to think
# Of any misery in the sound of the wind,
# In the sound of a few leaves,
# Which is the sound of the land
# Full of the same wind
# That is blowing in the same bare place
# For the listener, who listens in the snow,
# And, nothing himself, beholds
# Nothing that is not there and the nothing that is.
#
# New Poem (P+7):
# --------------------------------------------------
# Text: One must have a mind of
# Top 7 words: their, its, his, your, a, our, **her**
# ------------------------------
# Text: To regard the frost and the
# Top 7 words: cold, snow, frost, ice, fire, wind, **death**
# ------------------------------
# Text: Of the pine-trees crusted with
# Top 7 words: the, a, pine, salt, blood, red, **oil**
# ------------------------------
# Text: And have been cold a long
# Top 7 words: time, while, ,, enough, long, day, **way**
# ------------------------------
# Text: To behold the junipers shagged with
# Top 7 words: the, their, a, blood, an, black, **white**
# ------------------------------
# Text: The spruces rough in the distant
# Top 7 words: hills, past, mountains, ,, sky, future, **horizon**
# ------------------------------
# Text: Of the January sun; and not to
# Top 7 words: be, mention, the, say, forget, speak, **have**
# ------------------------------
# Text: Of any misery in the sound of the
# Top 7 words: trumpet, voice, bell, world, bells, wind, **sound**
# ------------------------------
# Text: In the sound of a few
# Top 7 words: words, voices, of, gunshots, feet, clicks, **shots**
# ------------------------------
# Text: Which is the sound of the
# Top 7 words: wind, car, door, engine, water, sound, **voice**
# ------------------------------
# Text: Full of the same
# Top 7 words: ,, ., kind, name, thing, type, **day**
# ------------------------------
# Text: That is blowing in the same bare
# Top 7 words: -, foot, feet, chest, hands, ,, **air**
# ------------------------------
# Text: For the listener, who listens in the
# Top 7 words: background, same, middle, first, browser, ", **morning**
# ------------------------------
# Text: And, nothing himself,
# Top 7 words: but, nothing, except, no, and, he, **I**
# ------------------------------
# Text: Nothing that is not there and the nothing that
# Top 7 words: is, has, does, was, I, we, **isn**
# ------------------------------
# One must have a mind of her
# To regard the frost and the death
# Of the pine-trees crusted with oil
# And have been cold a long way
# To behold the junipers shagged with white
# The spruces rough in the distant horizon
# Of the January sun; and not to have
# Of any misery in the sound of the sound
# In the sound of a few shots
# Which is the sound of the voice
# Full of the same day
# That is blowing in the same bare air
# For the listener, who listens in the morning
# And, nothing himself, I
# Nothing that is not there and the nothing that isn

# %% [markdown]
# # P+70

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch
import torch.nn.functional as F

# Load the model and tokenizer only once
gpt2_model = GPT2LMHeadModel.from_pretrained('gpt2')
gpt2_tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
gpt2_model.eval()

def predict_next_word(text_input):

    encoded_input = gpt2_tokenizer.encode(text_input, return_tensors='pt')

    with torch.no_grad():
        model_output = gpt2_model(encoded_input)
        word_predictions = model_output[0]

    next_word_logits = word_predictions[0, -1, :]
    word_probabilities = F.softmax(next_word_logits, dim=0)

    # Change k to 70 to get the top 70 predictions
    top_probs, top_indices = torch.topk(word_probabilities, k=70)
    predicted_words = [gpt2_tokenizer.decode(idx.item()).strip() for idx in top_indices]

    # Adjust index to 69 to return the 70th word
    highlighted_words = ', '.join(
        f"**{word}**" if i == 69 else word for i, word in enumerate(predicted_words)
    )
    print(f"Text: {text_input}\nTop 70 words: {highlighted_words}\n{'-' * 30}")

    return predicted_words[69]  # Return the 70th word


def modify_poem(poem):
    poem_lines = [line.strip() for line in poem.split('\n') if line.strip()]
    updated_lines = []

    for current_line in poem_lines:
        line_words = current_line.split()
        if not line_words:
            updated_lines.append(current_line)
            continue

        line_context = ' '.join(line_words[:-1])
        replacement_word = predict_next_word(line_context)
        modified_line = f"{line_context} {replacement_word}"
        updated_lines.append(modified_line)

    return '\n'.join(updated_lines)


# Poem
poem = """One must have a mind of winter
To regard the frost and the boughs
Of the pine-trees crusted with snow;
And have been cold a long time
To behold the junipers shagged with ice,
The spruces rough in the distant glitter
Of the January sun; and not to think
Of any misery in the sound of the wind,
In the sound of a few leaves,
Which is the sound of the land
Full of the same wind
That is blowing in the same bare place
For the listener, who listens in the snow,
And, nothing himself, beholds
Nothing that is not there and the nothing that is."""

# Printing
print(f"Original Poem:\n{'-' * 50}\n{poem}\n")
print(f"New Poem (P+70):\n{'-' * 50}")
modified_poem = modify_poem(poem)
print(modified_poem)
# Out:
# Original Poem:
# --------------------------------------------------
# One must have a mind of winter
# To regard the frost and the boughs
# Of the pine-trees crusted with snow;
# And have been cold a long time
# To behold the junipers shagged with ice,
# The spruces rough in the distant glitter
# Of the January sun; and not to think
# Of any misery in the sound of the wind,
# In the sound of a few leaves,
# Which is the sound of the land
# Full of the same wind
# That is blowing in the same bare place
# For the listener, who listens in the snow,
# And, nothing himself, beholds
# Nothing that is not there and the nothing that is.
#
# New Poem (P+70):
# --------------------------------------------------
# Text: One must have a mind of
# Top 70 words: their, its, his, your, a, our, her, this, my, one, the, balance, ", what, it, some, ', good, how, steel, something, self, order, thy, humility, gold, mystery, an, mine, that, purpose, these, deep, wonder, yours, justice, history, theirs, pure, consistency, right, great, unity, high, awe, humor, integrity, common, humour, power, two, stone, matter, trust, transparency, His, harmony, peace, hard, mastery, flux, control, style, language, scale, action, gratitude, love, at, **rhythm**
# ------------------------------
# Text: To regard the frost and the
# Top 70 words: cold, snow, frost, ice, fire, wind, death, fall, heat, storm, other, rain, sun, water, lack, freezing, sudden, subsequent, destruction, darkness, dust, blood, light, loss, lightning, weather, thunder, smoke, th, burning, fact, winter, chill, great, falling, ensuing, moon, war, fog, effect, consequ, black, rising, earth, icy, dark, d, f, clouds, danger, melting, resulting, impact, need, hail, cloud, hot, s, mist, pain, winds, time, surrounding, bl, power, flames, ", m, p, **heavy**
# ------------------------------
# Text: Of the pine-trees crusted with
# Top 70 words: the, a, pine, salt, blood, red, oil, gold, black, white, moss, ash, their, leaves, dust, dirt, dried, fire, snow, his, yellow, ", smoke, sugar, honey, pollen, green, maple, an, so, poison, wax, dead, blue, cr, b, sand, water, sulfur, seeds, coal, wood, ashes, l, powdered, p, poisonous, cinnamon, garlic, sp, d, grease, all, flour, melted, inc, gr, c, human, pe, fruit, carbon, its, bark, some, toxic, her, ch, golden, **this**
# ------------------------------
# Text: And have been cold a long
# Top 70 words: time, while, ,, enough, long, day, way, few, time, and, moment, year, -, week, period, night, bit, stretch, number, hard, season, life, couple, times, ways, journey, lot, ., term, one, winter, longer, too, haul, month, amount, wait, rest, but, Time, run, whilst, distance, little, fucking, summer, weekend, minute, before, career, go, morning, shot, since, bunch, afternoon, damn, trip, place, t, very, stay, to, ago, yet, spell, (, more, for, **a**
# ------------------------------
# Text: To behold the junipers shagged with
# Top 70 words: the, their, a, blood, an, black, white, red, his, tw, its, iron, arrows, feathers, silver, her, sharp, some, yellow, two, my, gold, one, venom, long, green, l, all, fire, this, branches, razor, sp, g, great, blue, oil, crimson, m, thick, such, so, steel, mud, b, fl, our, ant, spears, golden, water, sand, heavy, bullets, stones, leaves, bright, sl, p, lightning, th, j, hair, sh, bl, these, dark, horns, wings, **dust**
# ------------------------------
# Text: The spruces rough in the distant
# Top 70 words: hills, past, mountains, ,, sky, future, horizon, night, woods, distance, shadows, morning, background, forest, corners, air, and, desert, valley, sun, light, valleys, trees, forests, north, blue, days, summer, dark, south, memory, skies, ., evening, wind, stars, black, world, fields, years, star, twilight, shadow, middle, darkness, countryside, sunset, h, corner, east, rain, green, moon, west, afternoon, streets, wood, mountain, land, sea, winter, hill, hours, landscape, city, part, grass, back, wilderness, **distant**
# ------------------------------
# Text: Of the January sun; and not to
# Top 70 words: be, mention, the, say, forget, speak, have, think, look, my, take, go, a, all, make, do, get, any, see, give, put, his, worry, this, fear, sleep, doubt, dwell, begin, tell, leave, touch, let, know, exceed, add, those, that, wonder, him, use, lose, light, return, ask, -, keep, write, blame, set, show, our, come, bring, me, such, their, disturb, talk, call, find, fall, them, an, fail, long, complain, prevent, her, **eat**
# ------------------------------
# Text: Of any misery in the sound of the
# Top 70 words: trumpet, voice, bell, world, bells, wind, sound, music, drum, earth, sun, waves, drums, war, door, sea, great, song, water, car, thunder, engine, gun, news, hum, words, heart, voices, beat, word, sword, moon, whole, alarm, cl, man, waters, day, English, old, last, mighty, ocean, whistle, city, rain, horns, river, horn, whip, air, people, noise, dead, stream, house, enemy, trump, roar, crowd, gospel, beating, s, two, name, ch, breath, fire, morning, **hammer**
# ------------------------------
# Text: In the sound of a few
# Top 70 words: words, voices, of, gunshots, feet, clicks, shots, more, minutes, loud, seconds, explosions, footsteps, people, taps, bells, lines, fingers, r, ,, moments, hundred, bars, cheers, sentences, hours, other, p, high, quick, cl, thousand, broken, years, small, s, j, horns, screams, notes, familiar, long, dozen, ", voice, thunder, things, days, new, t, short, w, heavy, th, old, simple, ch, laughs, angry, gunshot, bullets, h, hits, breaths, hands, sn, months, songs, bell, **steps**
# ------------------------------
# Text: Which is the sound of the
# Top 70 words: wind, car, door, engine, water, sound, voice, bell, drum, music, gun, sun, ship, fire, man, air, waves, bird, thunder, phone, boat, song, sea, explosion, rain, horn, dog, trumpet, crowd, drums, earth, world, two, ocean, moon, police, war, ground, birds, ball, metal, machine, cl, engines, storm, woman, train, helicopter, guitar, first, s, sky, last, bells, clock, sword, words, people, hammer, word, noise, knife, horse, building, river, cat, news, wood, radio, **bullet**
# ------------------------------
# Text: Full of the same
# Top 70 words: ,, ., kind, name, thing, type, day, material, story, time, sort, year, color, :, , size, and, way, character, weight, as, stuff, old, in, substance, people, nature, for, idea, colour, amount, class, colors, is, level, things, game, -, but, order, (, to, or, can, spirit, quality, group, with, flavor, !, product, week, basic, effect, ", style, brand, problem, design, age, number, I, ;, .", magnitude, that, reason, form, season, **shape**
# ------------------------------
# Text: That is blowing in the same bare
# Top 70 words: -, foot, feet, chest, hands, ,, air, shoulders, footed, bones, head, hand, space, back, face, area, bottom, handed, water, skin, foot, back, palm, arms, spot, light, st, bones, toe, black, metal, white, pocket, and, blue, throat, wood, spots, dirt, hole, ., areas, body, shoulder, ground, front, middle, palms, minimum, pockets, heart, ness, hell, kn, corner, eyes, ton, shell, earth, river, rock, corners, concrete, ass, room, sockets, brush, surface, voice, **wind**
# ------------------------------
# Text: For the listener, who listens in the
# Top 70 words: background, same, middle, first, browser, ", morning, following, main, studio, most, order, room, default, form, direction, context, current, audio, usual, right, next, second, back, ', center, audience, front, loop, listener, channel, app, way, full, original, other, headphones, real, box, normal, open, above, near, early, upper, ear, dark, foreground, podcast, presence, traditional, standard, top, opposite, Spotify, demo, listening, new, sound, virtual, mode, car, meantime, public, evening, live, exact, wrong, home, **past**
# ------------------------------
# Text: And, nothing himself,
# Top 70 words: but, nothing, except, no, and, he, I, not, or, though, it, of, as, for, however, so, that, the, just, only, nor, this, because, in, which, really, even, to, if, save, there, although, what, you, at, let, since, nobody, by, other, they, anything, a, all, everything, none, his, from, unless, with, , either, she, neither, never, whatever, who, we, ever, is, absolutely, without, including, any, much, besides, apart, perhaps, anyway, **yet**
# ------------------------------
# Text: Nothing that is not there and the nothing that
# Top 70 words: is, has, does, was, I, we, isn, 's, you, comes, exists, can, cannot, will, doesn, it, goes, never, would, remains, happens, they, the, makes, there, seems, needs, not, belongs, he, could, no, should, appears, lies, may, follows, moves, gets, must, hasn, just, really, still, are, keeps, only, did, might, came, surrounds, takes, wasn, that, passes, looks, stands, nothing, she, actually, ,, occurs, gives, stays, touches, in, happened, becomes, flows, **lives**
# ------------------------------
# One must have a mind of rhythm
# To regard the frost and the heavy
# Of the pine-trees crusted with this
# And have been cold a long a
# To behold the junipers shagged with dust
# The spruces rough in the distant distant
# Of the January sun; and not to eat
# Of any misery in the sound of the hammer
# In the sound of a few steps
# Which is the sound of the bullet
# Full of the same shape
# That is blowing in the same bare wind
# For the listener, who listens in the past
# And, nothing himself, yet
# Nothing that is not there and the nothing that lives
